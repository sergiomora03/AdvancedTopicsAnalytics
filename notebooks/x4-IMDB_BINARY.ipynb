# %% [markdown]
# <a href="https://colab.research.google.com/github/sergiomora03/AdvancedTopicsAnalytics/blob/main/notebooks/x4-IMDB_BINARY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
# !pip install -q torch-scatter~=2.1.0 torch-sparse~=0.6.16 torch-cluster~=1.6.0 torch-spline-conv~=1.2.1 torch-geometric==2.2.0 -f https://data.pyg.org/whl/torch-{torch.__version__}.html

torch.manual_seed(0)
torch.cuda.manual_seed(0)
torch.cuda.manual_seed_all(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 51.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 49.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 67.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 886.6/886.6 kB 42.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.0/565.0 kB 5.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
from torch_geometric.datasets import TUDataset
import pandas as pd

# Donwload all 600 graphs
dataset = TUDataset(root='.', name='IMDB-BINARY')
# Out:
# ...
# Extracting ./IMDB-BINARY/IMDB-BINARY.zip
# Processing...
# Done!

# %%
[i for i in dataset]
# Out:
# [Data(edge_index=[2, 146], y=[1], num_nodes=20),
#  Data(edge_index=[2, 256], y=[1], num_nodes=32),
#  Data(edge_index=[2, 162], y=[1], num_nodes=21),
#  Data(edge_index=[2, 266], y=[1], num_nodes=35),
#  Data(edge_index=[2, 112], y=[1], num_nodes=14),
#  Data(edge_index=[2, 422], y=[1], num_nodes=63),
#  Data(edge_index=[2, 132], y=[1], num_nodes=12),
#  Data(edge_index=[2, 126], y=[1], num_nodes=15),
#  Data(edge_index=[2, 306], y=[1], num_nodes=18),
#  Data(edge_index=[2, 132], y=[1], num_nodes=12),
#  Data(edge_index=[2, 76], y=[1], num_nodes=12),
#  Data(edge_index=[2, 380], y=[1], num_nodes=20),
#  Data(edge_index=[2, 110], y=[1], num_nodes=13),
#  Data(edge_index=[2, 240], y=[1], num_nodes=20),
#  Data(edge_index=[2, 516], y=[1], num_nodes=72),
#  Data(edge_index=[2, 380], y=[1], num_nodes=20),
#  Data(edge_index=[2, 246], y=[1], num_nodes=18),
#  Data(edge_index=[2, 84], y=[1], num_nodes=12),
#  Data(edge_index=[2, 114], y=[1], num_nodes=19),
# ...

# %%
dataset[0]
# Out:
# Data(edge_index=[2, 146], y=[1], num_nodes=20)

# %%
data = dataset[0]

# %%
pd.DataFrame(data.edge_index.numpy().T, columns=['start_node','end_node'])
# Out:
#      start_node  end_node
# 0             0         2
# 1             0         4
# 2             0         5
# 3             0         9
# 4             0        10
# ..          ...       ...
# 141          19        14
# 142          19        15
# 143          19        16
# 144          19        17
# 145          19        18
#
# [146 rows x 2 columns]

# %%
# Print information about the dataset
print(f'Dataset: {dataset}')
print('-----------------------')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')

# Print information about the graph
print(f'\nGraph:')
print('------')
print(f'Edges are directed: {data.is_directed()}')
print(f'Graph has isolated nodes: {data.has_isolated_nodes()}')
print(f'Graph has loops: {data.has_self_loops()}')
# Out:
# Dataset: IMDB-BINARY(1000)
# -----------------------
# Number of graphs: 1000
# Number of features: 0
# Number of classes: 2
#
# Graph:
# ------
# Edges are directed: False
# Graph has isolated nodes: False
# Graph has loops: False
